# %% [markdown]
# ## 1 Write a program to check whether the first and last digit of a number are equal(without converting to string)

# %% [markdown]
# number =  int(input("enter a number"))
# if first

# %% [markdown]
# ## 2 write a program to display "solid", "liquid", or "gas" based on the temperature of water in C.

# %%
temp= int(input("enter temperature of water in C"))
if temp<0:
  print( "solid")
else :
 print ("gas")
elif temp>0
 print("liquid")
# Out:
#   Cell In[8], line 6
#     elif temp>0
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3 write a program to check whether both number are odd, both are even or one of each

# %%
a= int(input("enter first number"))
b= int(input("enter second number"))
if

# %% [markdown]
# ## 4  write a program to Check whether a number is closer to 10 or 20

# %%
n= int(input("enter number "))
a=10
b=20
if a==10:
 print ("number is closer")
# Out:
# enter number  80
# number is closer

# %% [markdown]
# ## 5  write a program to check whether a person can withdraw an amount based on current balance

# %% [markdown]
# ## 6  write a program to Check whether a given number ends with digit 0 or 5

# %%
n= int(input("enter number"))
if n=

# %% [markdown]
# ## 7  write a program Check whether height above 140 cm and weight below 120 kg

# %%
height = int(input("enter height"))
weight =int(input("enter weight"))
if height>140 and weight<120:
            print("right")
else: 
            print ("not right")
# Out:
# enter height 45
# enter weight 58
# not right

# %% [markdown]
# ## 8 Given three lengths, prints "can form triangle" if each side is less than the sum of the other two; else "cannot".

# %%
a= int(input("enter first side"))
b=int(input("enter second side"))
c= int (input("enter third side")) 
if a=b= c
 print("triangle")
else
print ("not triangle")
# Out:
#   Cell In[27], line 4
#     if a=b= c
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 9 write a program that compares two temperature readings and prints which one is higher, along with the difference.

# %%
a=int(input("enter fist number"))
b= int(input("enter second number"))
if

# %% [markdown]
# ## 10 Write a program to check whether two given number are both multiples of 4.

# %%
a= int(input("enter first number"))
b= int(input("enter second number"))
       if a%4
       print("multiples of 4")
else
       print("not multiples of 4")
# Out:
#   Cell In[30], line 3
#     if a/4
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## 11 Write a program to checkk whether two given number are both from the set {1,5,25,125,625,3125}

# %%
a=int(input("enter first number"))
b= int(input("enter second number"))
s={1,5,25,125,625,3125}
if a in s and b in s:
 print ("number are in set")
else:
print("number not in set")
# Out:
#   Cell In[39], line 7
#     print("number not in set")
#     ^
# IndentationError: expected an indented block after 'else' statement on line 6
