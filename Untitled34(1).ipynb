# %%
def add():
    a= int(input("enter a number"))
    b=int(input("enter a number"))
    print(a + b)

# %%
division()
# Out:
# enter a number 5
# enter a number 5
# division 1.0
# floor 1
# modulus 0

# %%
add()
# Out:
# enter a number 5
# enter a number 6
# 11

# %%
Write different functions for multiplication, substraction, division

# %%
def multi ():
    a=int(input("enter a number"))
    b=int(input("enter a number"))
    print(a*b)

# %%
multi()
# Out:
# enter a number 4
# enter a number 2
# 8

# %%
def sub():
    a=int(input("enter a number"))
    b=int(input("enter a number"))
    print(a-b)

# %%
sub()
# Out:
# enter a number 5
# enter a number 5
# 0

# %%
def div():
    a= int(input("enter a number"))
    b=int(input("enter a number"))
    print(a/b)

# %%
div()
# Out:
# enter a number 5
# enter a number 6
# 0.8333333333333334

# %%
def mult():
    a=int(input("enter a number"))
    b=int(input("enter a number"))
    m= a*b
    s=a-b
    d=a/b
    print("Multiplication",m)
    print("Substract",s)
    print("Division",d)
mult()
# Out:
# enter a number 5
# enter a number 7
# Multiplication 35
# Substract -2
# Division 0.7142857142857143

# %%
Write a function which will accept 2 numbers from used and return their division, floor division, modulus

# %%
def division():
    a=int(input("enter a number"))
    b=int(input("enter a number"))
    d = a / b
    f = a // b
    m = a % b   
    print("division",d)
    print("floor",f)
    print("modulus",m)
division()
# Out:
# enter a number 5
# enter a number 4
# division 1.25
# floor 1
# modulus 1

# %%
Write a function to find area of rectangle

# %%
def area():
    l=int(input("enter a lenght"))
    w=int(input("enter a width"))
    print(l*w)
area()
# Out:
# enter a lenght 20
# enter a width 20
# 400

# %%
Write a function to find area of circle

# %%
def circle():
    area=pi * radius*radius
    pi=3.14159
    print(area)

# %%
def circle():
    r=float(input("enter radius"))
    print(r)
circle()
# Out:
# enter radius 45
# 45.0

# %%
5. Write a function to find even and odd numbers, take number as user input

# %%
def num():
    n=int(input("enter a number"))
    if n % 2==0:
        print("even")
    else:
        print("odd")
num()
# Out:
# enter a number 67
# odd

# %%
def area():
    x= int(input("enter a number"))
    y= int(input("enter a number"))
    print(x*y)
area()
# Out:
# enter a number 10
# enter a number 20
# 200
