# %%
## 1 Write a python program to display all numbers between 50 and 100 that end with the digit 7

# %%
for i in range (50,101):
 if i % 10== 7:
    print (i)
# Out:
# 57
# 67
# 77
# 87
# 97

# %%
##2 Given an angle in degrees, print"Acute"(<90),"Right"(==90),"Obtuse"(90-180),"Straight"(==180), or"Reflex"(>180 and <360). If outside 0-360,print"Invaild",If outside 0-360, print "Invaild".

# %%
user = int(input("enter a number"))
if user < 90:
    print("Acute")
elif user ==90:
    print("Right")
elif user (90-180):
      print("Obtuse")
elif user ==180:
  print("Straight")
elif user >180 and  user<360:
  print ("Reflex")
else:
  print("Invalid")
# Out:
# enter a number 45
# Acute

# %%
## 3 Given tenure_months and salary, print "Waiver" if tenure_months>60 or salary<20000;else"No Waiver".

# %%
a1=int(input("enter tenure"))
a2 = int(input("enter salary"))
if a1>60 and a2<20000:
     print("Wavier")
else:
    print("No Waiver")
# Out:
# enter tenure 56
# enter salary 77
# No Waiver

# %%
## 4 Given two rectangle(L1,W1) and [L2,W2], print whether the first fits inside the second without rotation (i.e.,L1<L2 and W1<W2)

# %%
r1 = int(input("enter l1"))
r2 = int(input("enter l2"))
r3 = int(input("enter l3"))
r4 = int(input("enter l4"))
if l1>= l2 and w1>=w2:
    print("fits")
else:
    print("not fits")
# Out:
# enter l1 56
# enter l2 56
# enter l3 56
# enter l4 56
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 r3 = int(input("enter l3"))
#       4 r4 = int(input("enter l4"))
# ----> 5 if l1>= l2 and w1>=w2:
#       6     print("fits")
#       7 else:
#
# NameError: name 'l1' is not defined

# %%
## 5 Given closed intervals [a,b] and [c,d] with a<b and c<d, print "Over lap", "Touch" (meet at a point), or "Disjoint".

# %%
a= int(input("enter a"))
b= int(input("enter b"))
c= int(input("enter c"))
d= int(input("enter d"))
if a<b or

# %%
## 6 Given two three digit integers, print whether they contain exactly the same digits(in any order)
